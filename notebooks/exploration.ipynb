# %% [markdown]
# # Exploración de Datos
# Este notebook está diseñado para realizar un análisis exploratorio de los datos crudos y procesados.

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar Datos
# Cargar los datos desde la carpeta `data/raw` para comenzar el análisis.

# %%
# Cargar datos crudos
raw_data = pd.read_csv('../data/raw/dataset.csv')
raw_data.head()
